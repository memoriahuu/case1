# %% [markdown]
# pump_data.zip
#       ↓
# 真实 Pump measurements
# (Q, RPM, H)
#       ↓
# Visualize_Pump_Data.ipynb
#       ↓
# 先理解数据长什么样
#       ↓
# Curve_Fitting_Residuals.ipynb
#       ↓
# 理解 Q、RPM、H 之间的关系
# 以及 prediction error
#       ↓
# 你自己的模型
#       ↓
# H = f(Q, RPM)
#       ↓
# 检查 prediction error 是否 ≤ 5%
