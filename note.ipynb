# %% [markdown]
# pump_data.zip
#       ↓
# Real pump measurements
# (Q, RPM, H)
#       ↓
# Visualize_Pump_Data.ipynb
#       ↓
# First understand what the data looks like
#       ↓
# Curve_Fitting_Residuals.ipynb
#       ↓
# Understand the relationship among Q, RPM, and H
# as well as prediction error
#       ↓
# Your own model
#       ↓
# H = f(Q, RPM)
#       ↓
# Check whether prediction error is ≤ 5%
